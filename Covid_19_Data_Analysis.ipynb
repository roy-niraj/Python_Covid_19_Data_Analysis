# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('covid_19_dataset.csv')

# %%
data.head(10)
# Out:
#              State               Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN          Afghanistan       1939      60        252
# 1  4/29/2020   NaN              Albania        766      30        455
# 2  4/29/2020   NaN              Algeria       3848     444       1702
# 3  4/29/2020   NaN              Andorra        743      42        423
# 4  4/29/2020   NaN               Angola         27       2          7
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11
# 6  4/29/2020   NaN            Argentina       4285     214       1192
# 7  4/29/2020   NaN              Armenia       1932      30        900
# 8  4/29/2020   NaN              Austria      15402     580      12779
# 9  4/29/2020   NaN           Azerbaijan       1766      23       1267

# %%
data.count()
# Out:
#              321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
#                0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# ### 1) show the number of confirm death and recovered cases in each region.

# %%
data.head(2)
# Out:
#              State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(50)
# Out:
# Region
# US                      1039909
# Spain                    236899
# Italy                    203591
# France                   166543
# UK                       166441
# Germany                  161539
# Turkey                   117589
# Russia                    99399
# Iran                      93657
# Mainland China            82862
# Brazil                    79685
# Canada                    52865
# Belgium                   47859
# Netherlands               38998
# Peru                      33931
# India                     33062
# Switzerland               29407
# Ecuador                   24675
# Portugal                  24505
# Saudi Arabia              21402
# Sweden                    20302
# Ireland                   20253
# Mexico                    17799
# Israel                    15834
# Singapore                 15641
# Pakistan                  15525
# Austria                   15402
# Chile                     14885
# Japan                     13895
# ...

# %%
data.groupby('Region')[['Confirmed','Recovered']].sum()
# Out:
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# ### 2) Remove all the records where confirm cases is less than 10.

# %%
data[data.Confirmed < 10 ]
#data[~data.Confirmed < 10 ]      it remove temporary but it mekes like data frame the delete parmanent .
# data = data[~(data.confirmed < 10)]
# Out:
#                                            State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %% [markdown]
# ### 3) in which Region maximum number of confirm cases were recorded.

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending = False)
# Out:
# Region
# US                  1039909
# Spain                236899
# Italy                203591
# France               166543
# UK                   166441
#                      ...
# Mauritania                8
# Papua New Guinea          8
# Bhutan                    7
# Yemen                     6
# Western Sahara            6
# Name: Confirmed, Length: 187, dtype: int64

# %% [markdown]
# ### 4) In which Region , maximum cases of deaths cases were recorded.

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = False)
# Out:
# Region
# US                60967
# Italy             27682
# UK                26166
# Spain             24275
# France            24121
#                   ...
# South Sudan           0
# Uganda                0
# Vietnam               0
# Yemen                 0
# Western Sahara        0
# Name: Deaths, Length: 187, dtype: int64

# %% [markdown]
# ### 5) how many confirm deaths & records case were reported from india till 29 april 2000.

# %%
data.head(2)
# Out:
#              State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data[data.Region == 'India']
# Out:
#               State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[data.Region == 'Indonesia']
# Out:
#               State     Region  Confirmed  Deaths  Recovered
# 75  4/29/2020   NaN  Indonesia       9771     784       1391

# %% [markdown]
# ### 6) Countries with zero deaths

# %%
data[data['Deaths'] == 0]
# Out:
#                                            State  \
# 18   4/29/2020                               NaN
# 29   4/29/2020                               NaN
# 31   4/29/2020                               NaN
# 45   4/29/2020                               NaN
# 51   4/29/2020                               NaN
# 55   4/29/2020                               NaN
# 64   4/29/2020                               NaN
# 70   4/29/2020                               NaN
# 90   4/29/2020                               NaN
# 99   4/29/2020                               NaN
# 110  4/29/2020                               NaN
# 113  4/29/2020                               NaN
# 114  4/29/2020                               NaN
# 115  4/29/2020                               NaN
# 126  4/29/2020                               NaN
# 135  4/29/2020                               NaN
# 136  4/29/2020                               NaN
# 137  4/29/2020                               NaN
# ...

# %% [markdown]
# ### 7) Countries with recovered > confirmed (data issue check)

# %%
data[data['Recovered'] > data['Confirmed']]
# Out:
#                     State  Region  Confirmed  Deaths  Recovered
# 284  4/29/2020  Recovered  Canada          0       0      20327
# 285  4/29/2020  Recovered      US          0       0     120720

# %% [markdown]
# ### 8) Country with highest active cases

# %%
#df['Active'] = df['Confirmed'] - df['Recovered'] - df['Deaths']
#df.loc[df['Active'].idxmax()]
data['Active'] = data['Confirmed'] - data['Recovered'] - data['Deaths']
data.loc[data['Active'].idxmax()]
# Out:
#              4/29/2020
# State         New York
# Region              US
# Confirmed       299691
# Deaths           23477
# Recovered            0
# Active          276214
# Name: 265, dtype: object

# %% [markdown]
# ### 9) Which country has the highest recovery rate?

# %%
data['RecoveryRate'] = (data['Recovered'] / data['Confirmed']) * 100
data.loc[data['RecoveryRate'].idxmax()]
# Out:
#                 4/29/2020
# State           Recovered
# Region             Canada
# Confirmed               0
# Deaths                  0
# Recovered           20327
# Active             -20327
# RecoveryRate          inf
# Name: 284, dtype: object

# %% [markdown]
# ### 10) List all countries where active cases are more than 50% of confirmed cases.

# %%
df['Active'] = df['Confirmed'] - df['Recovered'] - df['Deaths']
df[df['Active'] > 0.5 * df['Confirmed']]
data['Active'] = data['Confirmed'] - data['Recovered'] - data['Deaths']
data[data['Active']]
